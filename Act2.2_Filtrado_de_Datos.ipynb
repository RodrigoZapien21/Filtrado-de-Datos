# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Barcelona.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15406 entries, 0 to 15405
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15406 non-null  int64
#  1   name                            15406 non-null  object
#  2   host_id                         15293 non-null  float64
#  3   host_profile_id                 15212 non-null  float64
#  4   host_name                       15206 non-null  object
#  5   neighbourhood_group             15406 non-null  object
#  6   neighbourhood                   15406 non-null  object
#  7   latitude                        15406 non-null  float64
#  8   longitude                       15406 non-null  float64
#  9   room_type                       15406 non-null  object
#  10  price                           13465 non-null  float64
#  11  minimum_nights                  15405 non-null  float64
# ...

# %%
#Inciso A 
nombres_distintos = df['host_name'].unique()[:5] #definimos la variable donde se guardan los nombres, y se especifica que sean distintos y solo 5
filtroA = df[df['host_name'].isin(nombres_distintos)]
filtroA
# Out:
#                         id                                               name  \
# 0                    18674    Huge flat for 8 people close to Sagrada Familia
# 1                    23197     CCIB Forum· Large Balcony · 5 min walk to CCIB
# 2                    34981               VIDRE HOME PLAZA REAL on LAS RAMBLAS
# 3                    36763                              In front of the beach
# 4                    40983    Architect's Loft near Gaudí & Passeig de Gràcia
# 126                 569610   Pl España  / Sants Station / Perfect Remote Work
# 210                 775644                Stylish Apt w/Terrace | City Center
# 282                 934979                           Sagrada Familia charming
# 373                1119598                  Flat with views to Sagrada Famila
# 669                2288221         Elegant apartment in the heart of the city
# 695                2394424     Chic studio in a perfect location in Barcelona
# ...

# %%
filtroA.to_csv("Inciso A.csv")

# %% [markdown]
# ## LA HOJA DE DATOS DE MI PAÍS NO TIENE VARIABLE DE "HOST_SINCE" , "HOST_RESPONSE_TIME" , "BEDS"

# %%
# Inciso D
multiplos = df.iloc[200::200]
multiplos
# Out:
#                         id                                               name  \
# 200                 753322          Big beautiful apartment in Gracia 4 rooms
# 400                1198074                              Two bedroom apartment
# 600                1920941                       Luxurious & Loving Apartment
# 800                2996993                        Large two bedroom apartment
# 1000               4114081         Barcelona | Apt near Sagrada Familia for 6
# ...                    ...                                                ...
# 14600  1677477937703824479              Eixample town - 365 barcelona rentals
# 14800  1689843502743720327        Charming room near the beach and the center
# 15000  1698509847890521632  Cómoda habitación en la zona de montjuic con aire
# 15200  1708774165763933382   Cozy 3BR Apartment: Great Location in L'Eixample
# 15400  1714436799055988275             Tranquila habitación con balcón y a/a.
#
# ...

# %%
multiplos.to_csv("Inciso D.csv")

# %%
# Inciso E
tipos_cuartos = df[df['room_type'].isin(['Entire home/apt','Private room'])]
tipos_cuartos
# Out:
#                         id                                               name  \
# 0                    18674    Huge flat for 8 people close to Sagrada Familia
# 1                    23197     CCIB Forum· Large Balcony · 5 min walk to CCIB
# 2                    34981               VIDRE HOME PLAZA REAL on LAS RAMBLAS
# 3                    36763                              In front of the beach
# 4                    40983    Architect's Loft near Gaudí & Passeig de Gràcia
# ...                    ...                                                ...
# 15401  1714453367636295798  Sagrada Familia View — Diagonal White Loft T5A...
# 15402  1714507108958061169  Sagrada Familia - Diagonal Industrial Loft T5A...
# 15403  1714524223290226460  Cozy 2-Bedroom Apartment in Poble Sec for 4 pe...
# 15404  1714528494413566181      Poble Sec - Lovely 2BR Apartment with Terrace
# 15405  1714531569719409706   Great 2-Bedroom Apartment • Poble Sec • 4 people
#
# ...

# %%
tipos_cuartos.to_csv("Inciso E.csv")

# %%
columna_impares = df.iloc[:,1::2]
columna_impares
# Out:
#                                                     name  host_profile_id  \
# 0        Huge flat for 8 people close to Sagrada Familia     1.462508e+18
# 1         CCIB Forum· Large Balcony · 5 min walk to CCIB     1.462509e+18
# 2                   VIDRE HOME PLAZA REAL on LAS RAMBLAS     1.462508e+18
# 3                                  In front of the beach     1.462511e+18
# 4        Architect's Loft near Gaudí & Passeig de Gràcia     1.462512e+18
# ...                                                  ...              ...
# 15401  Sagrada Familia View — Diagonal White Loft T5A...     1.468178e+18
# 15402  Sagrada Familia - Diagonal Industrial Loft T5A...     1.468178e+18
# 15403  Cozy 2-Bedroom Apartment in Poble Sec for 4 pe...     1.462518e+18
# 15404      Poble Sec - Lovely 2BR Apartment with Terrace     1.462518e+18
# 15405   Great 2-Bedroom Apartment • Poble Sec • 4 people     1.462518e+18
#
#       neighbourhood_group   latitude        room_type  minimum_nights  \
# ...

# %%
columna_impares.to_csv("Inciso G.csv")
